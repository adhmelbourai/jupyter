# %% [markdown]
# #Hi

# %%
import socket
import select
list_connect=dict()
poll=select.poll()

# %%
sock=socket.socket(socket.AF_INET,socket.SOCK_STREAM)
sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_SYNCNT,3)
sock.setblocking(0)
sock.connect_ex(('8.8.8.8',53))
poll.register(sock.fileno(),select.POLLOUT)

# %%
poll.poll(1000)
# Out:
# [(44, 4)]

# %%
sock.getpeername()
# Out:
# ('8.8.8.8', 53)
